# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory

import os
print(os.listdir("../input"))

# Any results you write to the current directory are saved as output.
# Out:
# ['data.npy', 'labels.npy']

# %%
import keras
from keras.layers.core import Layer
import keras.backend as K
import tensorflow as tf
from keras.datasets import cifar10
from keras.models import Model
from keras.layers import Conv2D, MaxPool2D,  \
    Dropout, Dense, Input, concatenate,      \
    GlobalAveragePooling2D, AveragePooling2D,\
    Flatten
from sklearn.model_selection import train_test_split
from keras.utils import to_categorical

import cv2 
import numpy as np 
from keras.datasets import cifar10 
from keras import backend as K 
from keras.utils import np_utils

import math 
from keras.optimizers import SGD 
from keras.callbacks import LearningRateScheduler
data=np.load('../input/data.npy')
labels=np.load('../input/labels.npy')
# partition the data into training and testing splits using 75% of
# the data for training and the remaining 25% for testing
(X_train, X_test, y_train, y_test) = train_test_split(data,
	labels, test_size=0.25, random_state=6)

# convert the labels from integers to vectors
y_train = to_categorical(y_train, num_classes=2)
y_test = to_categorical(y_test, num_classes=2)

def inception_module(x,
                     filters_1x1,
                     filters_3x3_reduce,
                     filters_3x3,
                     filters_5x5_reduce,
                     filters_5x5,
                     filters_pool_proj,
                     name=None):
    
    conv_1x1 = Conv2D(filters_1x1, (1, 1), padding='same', activation='relu')(x)
    
    conv_3x3 = Conv2D(filters_3x3_reduce, (1, 1), padding='same', activation='relu')(x)
    conv_3x3 = Conv2D(filters_3x3, (3, 3), padding='same', activation='relu')(conv_3x3)

    conv_5x5 = Conv2D(filters_5x5_reduce, (1, 1), padding='same', activation='relu')(x)
    conv_5x5 = Conv2D(filters_5x5, (5, 5), padding='same', activation='relu')(conv_5x5)

    pool_proj = MaxPool2D((3, 3), strides=(1, 1), padding='same')(x)
    pool_proj = Conv2D(filters_pool_proj, (1, 1), padding='same', activation='relu')(pool_proj)

    output = concatenate([conv_1x1, conv_3x3, conv_5x5, pool_proj], axis=3, name=name)
    
    return output




kernel_init = keras.initializers.glorot_uniform()
bias_init = keras.initializers.Constant(value=0.2)

input_layer = Input(shape=(128, 128, 3))

x = Conv2D(64, (7, 7), padding='same', strides=(2, 2), activation='relu', name='conv_1_7x7/2')(input_layer)
x = MaxPool2D((3, 3), padding='same', strides=(2, 2), name='max_pool_1_3x3/2')(x)
x = Conv2D(64, (1, 1), padding='same', strides=(1, 1), activation='relu', name='conv_2a_3x3/1')(x)
x = Conv2D(192, (3, 3), padding='same', strides=(1, 1), activation='relu', name='conv_2b_3x3/1')(x)
x = MaxPool2D((3, 3), padding='same', strides=(2, 2), name='max_pool_2_3x3/2')(x)

x = inception_module(x,
                     filters_1x1=64,
                     filters_3x3_reduce=96,
                     filters_3x3=128,
                     filters_5x5_reduce=16,
                     filters_5x5=32,
                     filters_pool_proj=32,
                     name='inception_3a')

x = inception_module(x,
                     filters_1x1=128,
                     filters_3x3_reduce=128,
                     filters_3x3=192,
                     filters_5x5_reduce=32,
                     filters_5x5=96,
                     filters_pool_proj=64,
                     name='inception_3b')

x = MaxPool2D((3, 3), padding='same', strides=(2, 2), name='max_pool_3_3x3/2')(x)

x = inception_module(x,
                     filters_1x1=192,
                     filters_3x3_reduce=96,
                     filters_3x3=208,
                     filters_5x5_reduce=16,
                     filters_5x5=48,
                     filters_pool_proj=64,
                     name='inception_4a')


x1 = AveragePooling2D((5, 5), strides=3)(x)
x1 = Conv2D(128, (1, 1), padding='same', activation='relu')(x1)
x1 = Flatten()(x1)
x1 = Dense(1024, activation='relu')(x1)
x1 = Dropout(0.7)(x1)
x1 = Dense(2, activation='softmax', name='auxilliary_output_1')(x1)

    x = inception_module(x,
                         filters_1x1=160,
                         filters_3x3_reduce=112,
                         filters_3x3=224,
                         filters_5x5_reduce=24,
                         filters_5x5=64,
                         filters_pool_proj=64,
                         name='inception_4b')

    x = inception_module(x,filters_1x1=128,filters_3x3_reduce=128,filters_3x3=256,filters_5x5_reduce=24,
 filters_5x5=64, filters_pool_proj=64,
 name='inception_4c')

    x = inception_module(x,filters_1x1=112,filters_3x3_reduce=144,
filters_3x3=288,filters_5x5_reduce=32,filters_5x5=64,filters_pool_proj=64, name='inception_4d')


    x2 = AveragePooling2D((5, 5), strides=3)(x)
    x2 = Conv2D(128, (1, 1), padding='same', activation='relu')(x2)
    x2 = Flatten()(x2)
    x2 = Dense(1024, activation='relu')(x2)
    x2 = Dropout(0.7)(x2)
    x2 = Dense(2, activation='softmax', name='auxilliary_output_2')(x2)

    x = inception_module(x,filters_1x1=256,filters_3x3_reduce=160,filters_3x3=320,filters_5x5_reduce=32,
filters_5x5=128,filters_pool_proj=128,name='inception_4e')

x = MaxPool2D((3, 3), padding='same', strides=(2, 2), name='max_pool_4_3x3/2')(x)

x = inception_module(x,
filters_1x1=256,
filters_3x3_reduce=160,
filters_3x3=320,
filters_5x5_reduce=32,
filters_5x5=128,
filters_pool_proj=128,
name='inception_5a')

x = inception_module(x,
                     filters_1x1=384,
                     filters_3x3_reduce=192,
                     filters_3x3=384,
                     filters_5x5_reduce=48,
                     filters_5x5=128,
                     filters_pool_proj=128,
                     name='inception_5b')

x = GlobalAveragePooling2D(name='avg_pool_5_3x3/1')(x)

x = Dropout(0.4)(x)

x = Dense(2, activation='softmax', name='output')(x)


model = Model(input_layer, [x, x1, x2], name='inception_v1')

model.summary()


epochs = 32
initial_lrate = 0.01

def decay(epoch, steps=100):
    initial_lrate = 0.01
    drop = 0.96
    epochs_drop = 8
    lrate = initial_lrate * math.pow(drop, math.floor((1+epoch)/epochs_drop))
    return lrate

sgd = SGD(lr=initial_lrate, momentum=0.9, nesterov=False)

lr_sc = LearningRateScheduler(decay, verbose=1)

model.compile(loss=['categorical_crossentropy', 'categorical_crossentropy', 'categorical_crossentropy'], loss_weights=[1, 0.3, 0.3], optimizer=sgd, metrics=['accuracy'])
history = model.fit(X_train, [y_train,y_train,y_train], validation_data=(X_test, [y_test,y_test,y_test]), epochs=epochs, batch_size=256, callbacks=[lr_sc])
# Out:
# Using TensorFlow backend.
# WARNING:tensorflow:From /opt/conda/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /opt/conda/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 128, 128, 3)  0
# __________________________________________________________________________________________________
# conv_1_7x7/2 (Conv2D)           (None, 64, 64, 64)   9472        input_1[0][0]
# __________________________________________________________________________________________________
# max_pool_1_3x3/2 (MaxPooling2D) (None, 32, 32, 64)   0           conv_1_7x7/2[0][0]
# __________________________________________________________________________________________________
# conv_2a_3x3/1 (Conv2D)          (None, 32, 32, 64)   4160        max_pool_1_3x3/2[0][0]
# __________________________________________________________________________________________________
# conv_2b_3x3/1 (Conv2D)          (None, 32, 32, 192)  110784      conv_2a_3x3/1[0][0]
# __________________________________________________________________________________________________
# max_pool_2_3x3/2 (MaxPooling2D) (None, 16, 16, 192)  0           conv_2b_3x3/1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 16, 16, 96)   18528       max_pool_2_3x3/2[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 16, 16, 16)   3088        max_pool_2_3x3/2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 16, 16, 192)  0           max_pool_2_3x3/2[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 16, 16, 64)   12352       max_pool_2_3x3/2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 16, 16, 128)  110720      conv2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 16, 16, 32)   12832       conv2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 16, 16, 32)   6176        max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# inception_3a (Concatenate)      (None, 16, 16, 256)  0           conv2d_1[0][0]
#                                                                  conv2d_3[0][0]
#                                                                  conv2d_5[0][0]
#                                                                  conv2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 16, 16, 128)  32896       inception_3a[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 16, 16, 32)   8224        inception_3a[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 16, 16, 256)  0           inception_3a[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 16, 16, 128)  32896       inception_3a[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 16, 16, 192)  221376      conv2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 16, 16, 96)   76896       conv2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 16, 16, 64)   16448       max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# inception_3b (Concatenate)      (None, 16, 16, 480)  0           conv2d_7[0][0]
#                                                                  conv2d_9[0][0]
#                                                                  conv2d_11[0][0]
#                                                                  conv2d_12[0][0]
# __________________________________________________________________________________________________
# max_pool_3_3x3/2 (MaxPooling2D) (None, 8, 8, 480)    0           inception_3b[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 8, 8, 96)     46176       max_pool_3_3x3/2[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 8, 8, 16)     7696        max_pool_3_3x3/2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 8, 8, 480)    0           max_pool_3_3x3/2[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 8, 8, 192)    92352       max_pool_3_3x3/2[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 8, 8, 208)    179920      conv2d_14[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 8, 8, 48)     19248       conv2d_16[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 8, 8, 64)     30784       max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# inception_4a (Concatenate)      (None, 8, 8, 512)    0           conv2d_13[0][0]
#                                                                  conv2d_15[0][0]
#                                                                  conv2d_17[0][0]
#                                                                  conv2d_18[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 8, 8, 112)    57456       inception_4a[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 8, 8, 24)     12312       inception_4a[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 8, 8, 512)    0           inception_4a[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 8, 8, 160)    82080       inception_4a[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 8, 8, 224)    226016      conv2d_21[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 8, 8, 64)     38464       conv2d_23[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 8, 8, 64)     32832       max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# inception_4b (Concatenate)      (None, 8, 8, 512)    0           conv2d_20[0][0]
#                                                                  conv2d_22[0][0]
#                                                                  conv2d_24[0][0]
#                                                                  conv2d_25[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 8, 8, 128)    65664       inception_4b[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 8, 8, 24)     12312       inception_4b[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_5 (MaxPooling2D)  (None, 8, 8, 512)    0           inception_4b[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 8, 8, 128)    65664       inception_4b[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 8, 8, 256)    295168      conv2d_27[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 8, 8, 64)     38464       conv2d_29[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 8, 8, 64)     32832       max_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# inception_4c (Concatenate)      (None, 8, 8, 512)    0           conv2d_26[0][0]
#                                                                  conv2d_28[0][0]
#                                                                  conv2d_30[0][0]
#                                                                  conv2d_31[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 8, 8, 144)    73872       inception_4c[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 8, 8, 32)     16416       inception_4c[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_6 (MaxPooling2D)  (None, 8, 8, 512)    0           inception_4c[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 8, 8, 112)    57456       inception_4c[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 8, 8, 288)    373536      conv2d_33[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 8, 8, 64)     51264       conv2d_35[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 8, 8, 64)     32832       max_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# inception_4d (Concatenate)      (None, 8, 8, 528)    0           conv2d_32[0][0]
#                                                                  conv2d_34[0][0]
#                                                                  conv2d_36[0][0]
#                                                                  conv2d_37[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 8, 8, 160)    84640       inception_4d[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 8, 8, 32)     16928       inception_4d[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_7 (MaxPooling2D)  (None, 8, 8, 528)    0           inception_4d[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 8, 8, 256)    135424      inception_4d[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 8, 8, 320)    461120      conv2d_40[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 8, 8, 128)    102528      conv2d_42[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 8, 8, 128)    67712       max_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# inception_4e (Concatenate)      (None, 8, 8, 832)    0           conv2d_39[0][0]
#                                                                  conv2d_41[0][0]
#                                                                  conv2d_43[0][0]
#                                                                  conv2d_44[0][0]
# __________________________________________________________________________________________________
# max_pool_4_3x3/2 (MaxPooling2D) (None, 4, 4, 832)    0           inception_4e[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, 4, 4, 160)    133280      max_pool_4_3x3/2[0][0]
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, 4, 4, 32)     26656       max_pool_4_3x3/2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_8 (MaxPooling2D)  (None, 4, 4, 832)    0           max_pool_4_3x3/2[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, 4, 4, 256)    213248      max_pool_4_3x3/2[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, 4, 4, 320)    461120      conv2d_46[0][0]
# __________________________________________________________________________________________________
# conv2d_49 (Conv2D)              (None, 4, 4, 128)    102528      conv2d_48[0][0]
# __________________________________________________________________________________________________
# conv2d_50 (Conv2D)              (None, 4, 4, 128)    106624      max_pooling2d_8[0][0]
# __________________________________________________________________________________________________
# inception_5a (Concatenate)      (None, 4, 4, 832)    0           conv2d_45[0][0]
#                                                                  conv2d_47[0][0]
#                                                                  conv2d_49[0][0]
#                                                                  conv2d_50[0][0]
# __________________________________________________________________________________________________
# conv2d_52 (Conv2D)              (None, 4, 4, 192)    159936      inception_5a[0][0]
# __________________________________________________________________________________________________
# conv2d_54 (Conv2D)              (None, 4, 4, 48)     39984       inception_5a[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_9 (MaxPooling2D)  (None, 4, 4, 832)    0           inception_5a[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_1 (AveragePoo (None, 2, 2, 512)    0           inception_4a[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_2 (AveragePoo (None, 2, 2, 528)    0           inception_4d[0][0]
# __________________________________________________________________________________________________
# conv2d_51 (Conv2D)              (None, 4, 4, 384)    319872      inception_5a[0][0]
# __________________________________________________________________________________________________
# conv2d_53 (Conv2D)              (None, 4, 4, 384)    663936      conv2d_52[0][0]
# __________________________________________________________________________________________________
# conv2d_55 (Conv2D)              (None, 4, 4, 128)    153728      conv2d_54[0][0]
# __________________________________________________________________________________________________
# conv2d_56 (Conv2D)              (None, 4, 4, 128)    106624      max_pooling2d_9[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 2, 2, 128)    65664       average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 2, 2, 128)    67712       average_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# inception_5b (Concatenate)      (None, 4, 4, 1024)   0           conv2d_51[0][0]
#                                                                  conv2d_53[0][0]
#                                                                  conv2d_55[0][0]
#                                                                  conv2d_56[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 512)          0           conv2d_19[0][0]
# __________________________________________________________________________________________________
# flatten_2 (Flatten)             (None, 512)          0           conv2d_38[0][0]
# __________________________________________________________________________________________________
# avg_pool_5_3x3/1 (GlobalAverage (None, 1024)         0           inception_5b[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 1024)         525312      flatten_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 1024)         525312      flatten_2[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 1024)         0           avg_pool_5_3x3/1[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 1024)         0           dense_1[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 1024)         0           dense_2[0][0]
# __________________________________________________________________________________________________
# output (Dense)                  (None, 2)            2050        dropout_3[0][0]
# __________________________________________________________________________________________________
# auxilliary_output_1 (Dense)     (None, 2)            2050        dropout_1[0][0]
# __________________________________________________________________________________________________
# auxilliary_output_2 (Dense)     (None, 2)            2050        dropout_2[0][0]
# ==================================================================================================
# Total params: 7,163,702
# Trainable params: 7,163,702
# Non-trainable params: 0
# __________________________________________________________________________________________________
# WARNING:tensorflow:From /opt/conda/lib/python3.6/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Train on 1671 samples, validate on 558 samples
# Epoch 1/32
#
# Epoch 00001: LearningRateScheduler setting learning rate to 0.01.
# 1671/1671 [==============================] - 9s 5ms/step - loss: 1.1090 - output_loss: 0.6931 - auxilliary_output_1_loss: 0.6931 - auxilliary_output_2_loss: 0.6933 - output_acc: 0.4955 - auxilliary_output_1_acc: 0.5117 - auxilliary_output_2_acc: 0.5015 - val_loss: 1.1087 - val_output_loss: 0.6929 - val_auxilliary_output_1_loss: 0.6930 - val_auxilliary_output_2_loss: 0.6930 - val_output_acc: 0.5000 - val_auxilliary_output_1_acc: 0.5000 - val_auxilliary_output_2_acc: 0.5000
# Epoch 2/32
#
# Epoch 00002: LearningRateScheduler setting learning rate to 0.01.
# 1671/1671 [==============================] - 2s 1ms/step - loss: 1.1086 - output_loss: 0.6929 - auxilliary_output_1_loss: 0.6926 - auxilliary_output_2_loss: 0.6931 - output_acc: 0.5105 - auxilliary_output_1_acc: 0.5177 - auxilliary_output_2_acc: 0.5099 - val_loss: 1.1082 - val_output_loss: 0.6926 - val_auxilliary_output_1_loss: 0.6926 - val_auxilliary_output_2_loss: 0.6928 - val_output_acc: 0.5000 - val_auxilliary_output_1_acc: 0.6183 - val_auxilliary_output_2_acc: 0.5000
# Epoch 3/32
#
# Epoch 00003: LearningRateScheduler setting learning rate to 0.01.
# 1671/1671 [==============================] - 2s 1ms/step - loss: 1.1081 - output_loss: 0.6925 - auxilliary_output_1_loss: 0.6925 - auxilliary_output_2_loss: 0.6929 - output_acc: 0.5913 - auxilliary_output_1_acc: 0.5380 - auxilliary_output_2_acc: 0.5206 - val_loss: 1.1074 - val_output_loss: 0.6920 - val_auxilliary_output_1_loss: 0.6920 - val_auxilliary_output_2_loss: 0.6926 - val_output_acc: 0.7258 - val_auxilliary_output_1_acc: 0.6720 - val_auxilliary_output_2_acc: 0.5000
# Epoch 4/32
#
# Epoch 00004: LearningRateScheduler setting learning rate to 0.01.
# 1671/1671 [==============================] - 3s 2ms/step - loss: 1.1070 - output_loss: 0.6919 - auxilliary_output_1_loss: 0.6914 - auxilliary_output_2_loss: 0.6925 - output_acc: 0.5937 - auxilliary_output_1_acc: 0.5595 - auxilliary_output_2_acc: 0.5554 - val_loss: 1.1062 - val_output_loss: 0.6911 - val_auxilliary_output_1_loss: 0.6912 - val_auxilliary_output_2_loss: 0.6923 - val_output_acc: 0.5681 - val_auxilliary_output_1_acc: 0.5717 - val_auxilliary_output_2_acc: 0.7688
# Epoch 5/32
#
# Epoch 00005: LearningRateScheduler setting learning rate to 0.01.
# 1671/1671 [==============================] - 3s 2ms/step - loss: 1.1058 - output_loss: 0.6908 - auxilliary_output_1_loss: 0.6911 - auxilliary_output_2_loss: 0.6924 - output_acc: 0.7157 - auxilliary_output_1_acc: 0.5703 - auxilliary_output_2_acc: 0.5673 - val_loss: 1.1046 - val_output_loss: 0.6898 - val_auxilliary_output_1_loss: 0.6905 - val_auxilliary_output_2_loss: 0.6920 - val_output_acc: 0.6918 - val_auxilliary_output_1_acc: 0.6846 - val_auxilliary_output_2_acc: 0.7939
# Epoch 6/32
#
# Epoch 00006: LearningRateScheduler setting learning rate to 0.01.
# 1671/1671 [==============================] - 3s 2ms/step - loss: 1.1033 - output_loss: 0.6887 - auxilliary_output_1_loss: 0.6901 - auxilliary_output_2_loss: 0.6919 - output_acc: 0.7570 - auxilliary_output_1_acc: 0.6068 - auxilliary_output_2_acc: 0.6152 - val_loss: 1.1018 - val_output_loss: 0.6876 - val_auxilliary_output_1_loss: 0.6897 - val_auxilliary_output_2_loss: 0.6911 - val_output_acc: 0.6254 - val_auxilliary_output_1_acc: 0.6057 - val_auxilliary_output_2_acc: 0.7276
# Epoch 7/32
#
# Epoch 00007: LearningRateScheduler setting learning rate to 0.01.
# 1671/1671 [==============================] - 2s 1ms/step - loss: 1.0992 - output_loss: 0.6855 - auxilliary_output_1_loss: 0.6885 - auxilliary_output_2_loss: 0.6907 - output_acc: 0.6930 - auxilliary_output_1_acc: 0.6260 - auxilliary_output_2_acc: 0.6577 - val_loss: 1.0957 - val_output_loss: 0.6825 - val_auxilliary_output_1_loss: 0.6878 - val_auxilliary_output_2_loss: 0.6895 - val_output_acc: 0.7258 - val_auxilliary_output_1_acc: 0.6523 - val_auxilliary_output_2_acc: 0.7616
# Epoch 8/32
#
# Epoch 00008: LearningRateScheduler setting learning rate to 0.0096.
# 1671/1671 [==============================] - 2s 1ms/step - loss: 1.0929 - output_loss: 0.6801 - auxilliary_output_1_loss: 0.6868 - auxilliary_output_2_loss: 0.6891 - output_acc: 0.7600 - auxilliary_output_1_acc: 0.6469 - auxilliary_output_2_acc: 0.6972 - val_loss: 1.0886 - val_output_loss: 0.6766 - val_auxilliary_output_1_loss: 0.6854 - val_auxilliary_output_2_loss: 0.6880 - val_output_acc: 0.7903 - val_auxilliary_output_1_acc: 0.7796 - val_auxilliary_output_2_acc: 0.7814
# Epoch 9/32
#
# Epoch 00009: LearningRateScheduler setting learning rate to 0.0096.
# 1671/1671 [==============================] - 2s 1ms/step - loss: 1.0858 - output_loss: 0.6742 - auxilliary_output_1_loss: 0.6846 - auxilliary_output_2_loss: 0.6873 - output_acc: 0.7600 - auxilliary_output_1_acc: 0.6655 - auxilliary_output_2_acc: 0.7223 - val_loss: 1.0763 - val_output_loss: 0.6662 - val_auxilliary_output_1_loss: 0.6819 - val_auxilliary_output_2_loss: 0.6851 - val_output_acc: 0.7885 - val_auxilliary_output_1_acc: 0.7401 - val_auxilliary_output_2_acc: 0.7957
# Epoch 10/32
#
# Epoch 00010: LearningRateScheduler setting learning rate to 0.0096.
# 1671/1671 [==============================] - 3s 2ms/step - loss: 1.0735 - output_loss: 0.6640 - auxilliary_output_1_loss: 0.6804 - auxilliary_output_2_loss: 0.6845 - output_acc: 0.7618 - auxilliary_output_1_acc: 0.6906 - auxilliary_output_2_acc: 0.7289 - val_loss: 1.0600 - val_output_loss: 0.6526 - val_auxilliary_output_1_loss: 0.6766 - val_auxilliary_output_2_loss: 0.6814 - val_output_acc: 0.7903 - val_auxilliary_output_1_acc: 0.7885 - val_auxilliary_output_2_acc: 0.7903
# Epoch 11/32
#
# Epoch 00011: LearningRateScheduler setting learning rate to 0.0096.
# 1671/1671 [==============================] - 3s 2ms/step - loss: 1.0533 - output_loss: 0.6471 - auxilliary_output_1_loss: 0.6738 - auxilliary_output_2_loss: 0.6803 - output_acc: 0.7834 - auxilliary_output_1_acc: 0.7289 - auxilliary_output_2_acc: 0.7588 - val_loss: 1.0448 - val_output_loss: 0.6397 - val_auxilliary_output_1_loss: 0.6722 - val_auxilliary_output_2_loss: 0.6779 - val_output_acc: 0.7384 - val_auxilliary_output_1_acc: 0.6864 - val_auxilliary_output_2_acc: 0.7652
# Epoch 12/32
#
# Epoch 00012: LearningRateScheduler setting learning rate to 0.0096.
# 1671/1671 [==============================] - 3s 2ms/step - loss: 1.0316 - output_loss: 0.6287 - auxilliary_output_1_loss: 0.6686 - auxilliary_output_2_loss: 0.6743 - output_acc: 0.7648 - auxilliary_output_1_acc: 0.7211 - auxilliary_output_2_acc: 0.7451 - val_loss: 1.0022 - val_output_loss: 0.6040 - val_auxilliary_output_1_loss: 0.6594 - val_auxilliary_output_2_loss: 0.6681 - val_output_acc: 0.7742 - val_auxilliary_output_1_acc: 0.7473 - val_auxilliary_output_2_acc: 0.7885
# Epoch 13/32
#
# Epoch 00013: LearningRateScheduler setting learning rate to 0.0096.
# 1671/1671 [==============================] - 3s 2ms/step - loss: 0.9951 - output_loss: 0.5991 - auxilliary_output_1_loss: 0.6543 - auxilliary_output_2_loss: 0.6659 - output_acc: 0.7612 - auxilliary_output_1_acc: 0.7301 - auxilliary_output_2_acc: 0.7457 - val_loss: 0.9388 - val_output_loss: 0.5518 - val_auxilliary_output_1_loss: 0.6385 - val_auxilliary_output_2_loss: 0.6515 - val_output_acc: 0.7957 - val_auxilliary_output_1_acc: 0.7867 - val_auxilliary_output_2_acc: 0.7921
# Epoch 14/32
#
# Epoch 00014: LearningRateScheduler setting learning rate to 0.0096.
# 1671/1671 [==============================] - 2s 1ms/step - loss: 0.9431 - output_loss: 0.5572 - auxilliary_output_1_loss: 0.6370 - auxilliary_output_2_loss: 0.6494 - output_acc: 0.7504 - auxilliary_output_1_acc: 0.7385 - auxilliary_output_2_acc: 0.7522 - val_loss: 0.8780 - val_output_loss: 0.5070 - val_auxilliary_output_1_loss: 0.6107 - val_auxilliary_output_2_loss: 0.6261 - val_output_acc: 0.7814 - val_auxilliary_output_1_acc: 0.7742 - val_auxilliary_output_2_acc: 0.7885
# Epoch 15/32
#
# Epoch 00015: LearningRateScheduler setting learning rate to 0.0096.
# 1671/1671 [==============================] - 2s 1ms/step - loss: 1.2013 - output_loss: 0.7945 - auxilliary_output_1_loss: 0.6784 - auxilliary_output_2_loss: 0.6776 - output_acc: 0.5990 - auxilliary_output_1_acc: 0.5996 - auxilliary_output_2_acc: 0.5972 - val_loss: 1.1553 - val_output_loss: 0.7384 - val_auxilliary_output_1_loss: 0.6928 - val_auxilliary_output_2_loss: 0.6968 - val_output_acc: 0.5000 - val_auxilliary_output_1_acc: 0.5000 - val_auxilliary_output_2_acc: 0.5000
# Epoch 16/32
#
# Epoch 00016: LearningRateScheduler setting learning rate to 0.009216.
# 1671/1671 [==============================] - 2s 1ms/step - loss: 1.0947 - output_loss: 0.6870 - auxilliary_output_1_loss: 0.6775 - auxilliary_output_2_loss: 0.6815 - output_acc: 0.5254 - auxilliary_output_1_acc: 0.6391 - auxilliary_output_2_acc: 0.6391 - val_loss: 1.0622 - val_output_loss: 0.6583 - val_auxilliary_output_1_loss: 0.6685 - val_auxilliary_output_2_loss: 0.6778 - val_output_acc: 0.5000 - val_auxilliary_output_1_acc: 0.7455 - val_auxilliary_output_2_acc: 0.6057
# Epoch 17/32
#
# Epoch 00017: LearningRateScheduler setting learning rate to 0.009216.
# 1671/1671 [==============================] - 2s 1ms/step - loss: 1.0401 - output_loss: 0.6428 - auxilliary_output_1_loss: 0.6583 - auxilliary_output_2_loss: 0.6659 - output_acc: 0.6499 - auxilliary_output_1_acc: 0.7409 - auxilliary_output_2_acc: 0.7193 - val_loss: 1.0075 - val_output_loss: 0.6184 - val_auxilliary_output_1_loss: 0.6476 - val_auxilliary_output_2_loss: 0.6492 - val_output_acc: 0.7581 - val_auxilliary_output_1_acc: 0.7168 - val_auxilliary_output_2_acc: 0.7688
# Epoch 18/32
#
# Epoch 00018: LearningRateScheduler setting learning rate to 0.009216.
# 1671/1671 [==============================] - 2s 1ms/step - loss: 0.9855 - output_loss: 0.6046 - auxilliary_output_1_loss: 0.6303 - auxilliary_output_2_loss: 0.6395 - output_acc: 0.7714 - auxilliary_output_1_acc: 0.7481 - auxilliary_output_2_acc: 0.7756 - val_loss: 0.9417 - val_output_loss: 0.5757 - val_auxilliary_output_1_loss: 0.5998 - val_auxilliary_output_2_loss: 0.6201 - val_output_acc: 0.7849 - val_auxilliary_output_1_acc: 0.7885 - val_auxilliary_output_2_acc: 0.7867
# Epoch 19/32
#
# Epoch 00019: LearningRateScheduler setting learning rate to 0.009216.
# 1671/1671 [==============================] - 2s 1ms/step - loss: 0.9213 - output_loss: 0.5634 - auxilliary_output_1_loss: 0.5833 - auxilliary_output_2_loss: 0.6097 - output_acc: 0.7804 - auxilliary_output_1_acc: 0.7756 - auxilliary_output_2_acc: 0.7804 - val_loss: 0.9384 - val_output_loss: 0.5821 - val_auxilliary_output_1_loss: 0.5785 - val_auxilliary_output_2_loss: 0.6090 - val_output_acc: 0.7384 - val_auxilliary_output_1_acc: 0.7616 - val_auxilliary_output_2_acc: 0.7258
# Epoch 20/32
#
# Epoch 00020: LearningRateScheduler setting learning rate to 0.009216.
# 1671/1671 [==============================] - 2s 1ms/step - loss: 0.8720 - output_loss: 0.5329 - auxilliary_output_1_loss: 0.5495 - auxilliary_output_2_loss: 0.5809 - output_acc: 0.7834 - auxilliary_output_1_acc: 0.7750 - auxilliary_output_2_acc: 0.7858 - val_loss: 0.8410 - val_output_loss: 0.5147 - val_auxilliary_output_1_loss: 0.5241 - val_auxilliary_output_2_loss: 0.5636 - val_output_acc: 0.7903 - val_auxilliary_output_1_acc: 0.7921 - val_auxilliary_output_2_acc: 0.7885
# Epoch 21/32
#
# Epoch 00021: LearningRateScheduler setting learning rate to 0.009216.
# 1671/1671 [==============================] - 2s 1ms/step - loss: 0.8221 - output_loss: 0.5016 - auxilliary_output_1_loss: 0.5193 - auxilliary_output_2_loss: 0.5490 - output_acc: 0.7870 - auxilliary_output_1_acc: 0.7858 - auxilliary_output_2_acc: 0.7858 - val_loss: 1.1157 - val_output_loss: 0.7256 - val_auxilliary_output_1_loss: 0.6778 - val_auxilliary_output_2_loss: 0.6225 - val_output_acc: 0.6183 - val_auxilliary_output_1_acc: 0.5950 - val_auxilliary_output_2_acc: 0.6487
# Epoch 22/32
#
# Epoch 00022: LearningRateScheduler setting learning rate to 0.009216.
# 1671/1671 [==============================] - 2s 1ms/step - loss: 1.0178 - output_loss: 0.6411 - auxilliary_output_1_loss: 0.6319 - auxilliary_output_2_loss: 0.6238 - output_acc: 0.6738 - auxilliary_output_1_acc: 0.6738 - auxilliary_output_2_acc: 0.6643 - val_loss: 0.8883 - val_output_loss: 0.5486 - val_auxilliary_output_1_loss: 0.5559 - val_auxilliary_output_2_loss: 0.5765 - val_output_acc: 0.7419 - val_auxilliary_output_1_acc: 0.7419 - val_auxilliary_output_2_acc: 0.7186
# Epoch 23/32
#
# Epoch 00023: LearningRateScheduler setting learning rate to 0.009216.
# 1671/1671 [==============================] - 2s 1ms/step - loss: 0.9172 - output_loss: 0.5750 - auxilliary_output_1_loss: 0.5638 - auxilliary_output_2_loss: 0.5768 - output_acc: 0.7157 - auxilliary_output_1_acc: 0.7271 - auxilliary_output_2_acc: 0.7253 - val_loss: 0.8059 - val_output_loss: 0.4909 - val_auxilliary_output_1_loss: 0.5233 - val_auxilliary_output_2_loss: 0.5268 - val_output_acc: 0.7832 - val_auxilliary_output_1_acc: 0.7545 - val_auxilliary_output_2_acc: 0.7688
# Epoch 24/32
#
# Epoch 00024: LearningRateScheduler setting learning rate to 0.008847359999999999.
# 1671/1671 [==============================] - 2s 1ms/step - loss: 0.8339 - output_loss: 0.5161 - auxilliary_output_1_loss: 0.5296 - auxilliary_output_2_loss: 0.5299 - output_acc: 0.7648 - auxilliary_output_1_acc: 0.7463 - auxilliary_output_2_acc: 0.7588 - val_loss: 0.8234 - val_output_loss: 0.5043 - val_auxilliary_output_1_loss: 0.5366 - val_auxilliary_output_2_loss: 0.5269 - val_output_acc: 0.7814 - val_auxilliary_output_1_acc: 0.7258 - val_auxilliary_output_2_acc: 0.7437
# Epoch 25/32
#
# Epoch 00025: LearningRateScheduler setting learning rate to 0.008847359999999999.
# 1671/1671 [==============================] - 2s 1ms/step - loss: 0.8069 - output_loss: 0.5027 - auxilliary_output_1_loss: 0.5093 - auxilliary_output_2_loss: 0.5047 - output_acc: 0.7732 - auxilliary_output_1_acc: 0.7648 - auxilliary_output_2_acc: 0.7738 - val_loss: 0.8254 - val_output_loss: 0.5172 - val_auxilliary_output_1_loss: 0.5128 - val_auxilliary_output_2_loss: 0.5148 - val_output_acc: 0.7706 - val_auxilliary_output_1_acc: 0.7563 - val_auxilliary_output_2_acc: 0.7599
# Epoch 26/32
#
# Epoch 00026: LearningRateScheduler setting learning rate to 0.008847359999999999.
# 1671/1671 [==============================] - 2s 1ms/step - loss: 0.8109 - output_loss: 0.5051 - auxilliary_output_1_loss: 0.5130 - auxilliary_output_2_loss: 0.5063 - output_acc: 0.7690 - auxilliary_output_1_acc: 0.7666 - auxilliary_output_2_acc: 0.7684 - val_loss: 0.7586 - val_output_loss: 0.4746 - val_auxilliary_output_1_loss: 0.4750 - val_auxilliary_output_2_loss: 0.4718 - val_output_acc: 0.7867 - val_auxilliary_output_1_acc: 0.7849 - val_auxilliary_output_2_acc: 0.7832
# Epoch 27/32
#
# Epoch 00027: LearningRateScheduler setting learning rate to 0.008847359999999999.
# 1671/1671 [==============================] - 2s 1ms/step - loss: 0.7425 - output_loss: 0.4586 - auxilliary_output_1_loss: 0.4758 - auxilliary_output_2_loss: 0.4706 - output_acc: 0.7947 - auxilliary_output_1_acc: 0.7953 - auxilliary_output_2_acc: 0.7965 - val_loss: 0.7269 - val_output_loss: 0.4511 - val_auxilliary_output_1_loss: 0.4626 - val_auxilliary_output_2_loss: 0.4566 - val_output_acc: 0.7957 - val_auxilliary_output_1_acc: 0.7867 - val_auxilliary_output_2_acc: 0.7957
# Epoch 28/32
#
# Epoch 00028: LearningRateScheduler setting learning rate to 0.008847359999999999.
# 1671/1671 [==============================] - 2s 1ms/step - loss: 0.7275 - output_loss: 0.4504 - auxilliary_output_1_loss: 0.4686 - auxilliary_output_2_loss: 0.4551 - output_acc: 0.7983 - auxilliary_output_1_acc: 0.7929 - auxilliary_output_2_acc: 0.7965 - val_loss: 0.7168 - val_output_loss: 0.4445 - val_auxilliary_output_1_loss: 0.4584 - val_auxilliary_output_2_loss: 0.4493 - val_output_acc: 0.7957 - val_auxilliary_output_1_acc: 0.7885 - val_auxilliary_output_2_acc: 0.7885
# Epoch 29/32
#
# Epoch 00029: LearningRateScheduler setting learning rate to 0.008847359999999999.
# 1671/1671 [==============================] - 2s 1ms/step - loss: 0.7208 - output_loss: 0.4455 - auxilliary_output_1_loss: 0.4622 - auxilliary_output_2_loss: 0.4557 - output_acc: 0.7965 - auxilliary_output_1_acc: 0.7917 - auxilliary_output_2_acc: 0.7995 - val_loss: 0.7321 - val_output_loss: 0.4553 - val_auxilliary_output_1_loss: 0.4643 - val_auxilliary_output_2_loss: 0.4582 - val_output_acc: 0.7939 - val_auxilliary_output_1_acc: 0.7867 - val_auxilliary_output_2_acc: 0.7921
# Epoch 30/32
#
# Epoch 00030: LearningRateScheduler setting learning rate to 0.008847359999999999.
# 1671/1671 [==============================] - 3s 2ms/step - loss: 0.7642 - output_loss: 0.4753 - auxilliary_output_1_loss: 0.4814 - auxilliary_output_2_loss: 0.4817 - output_acc: 0.7876 - auxilliary_output_1_acc: 0.7852 - auxilliary_output_2_acc: 0.7893 - val_loss: 0.7909 - val_output_loss: 0.4982 - val_auxilliary_output_1_loss: 0.4850 - val_auxilliary_output_2_loss: 0.4905 - val_output_acc: 0.7616 - val_auxilliary_output_1_acc: 0.7778 - val_auxilliary_output_2_acc: 0.7688
# Epoch 31/32
#
# Epoch 00031: LearningRateScheduler setting learning rate to 0.008847359999999999.
# 1671/1671 [==============================] - 2s 1ms/step - loss: 0.7709 - output_loss: 0.4806 - auxilliary_output_1_loss: 0.4845 - auxilliary_output_2_loss: 0.4829 - output_acc: 0.7870 - auxilliary_output_1_acc: 0.7893 - auxilliary_output_2_acc: 0.7899 - val_loss: 0.7273 - val_output_loss: 0.4522 - val_auxilliary_output_1_loss: 0.4633 - val_auxilliary_output_2_loss: 0.4537 - val_output_acc: 0.7921 - val_auxilliary_output_1_acc: 0.7957 - val_auxilliary_output_2_acc: 0.7993
# Epoch 32/32
#
# Epoch 00032: LearningRateScheduler setting learning rate to 0.008493465599999998.
# 1671/1671 [==============================] - 2s 1ms/step - loss: 0.7136 - output_loss: 0.4421 - auxilliary_output_1_loss: 0.4571 - auxilliary_output_2_loss: 0.4479 - output_acc: 0.7995 - auxilliary_output_1_acc: 0.7971 - auxilliary_output_2_acc: 0.7995 - val_loss: 0.6991 - val_output_loss: 0.4334 - val_auxilliary_output_1_loss: 0.4470 - val_auxilliary_output_2_loss: 0.4387 - val_output_acc: 0.8029 - val_auxilliary_output_1_acc: 0.7993 - val_auxilliary_output_2_acc: 0.8011
